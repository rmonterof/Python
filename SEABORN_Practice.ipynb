# %% [markdown]
# <a href="https://colab.research.google.com/github/rmonterof/Python/blob/main/SEABORN_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Seaborn_Practice
# https://seaborn.pydata.org

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ##Displot

# %%
df= sns.load_dataset("planets")
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.sort_values("mass", ascending=False)
# Out:
#                method  number  orbital_period   mass  distance  year
# 321   Radial Velocity       1     2371.000000  25.00     37.05  2008
# 85    Radial Velocity       2      379.630000  21.42       NaN  2009
# 63    Radial Velocity       1      305.500000  20.60     92.51  2013
# 913   Radial Velocity       1      677.800000  19.80       NaN  2007
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df=sns.load_dataset("planets")
sns.displot(df["mass"], bins=10)

# %%
sns.displot(df["mass"], bins=10, kde=True)

# %%
sns.displot(df["mass"], bins=5)

# %%
df= sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.displot(df["embark_town"])

# %%
sns.displot(df["embark_town"], kde=True)

# %%
sns.displot(df["embark_town"], color="purple")

# %%
df=sns.load_dataset("titanic")
sns.displot(df, x="sex", y="embark_town", cmap="viridis")

# %%
df=sns.load_dataset("titanic")
sns.displot(df, x="sex", y="class", cmap="viridis")

# %%
df=sns.load_dataset("titanic")
sns.displot(df, x="alive", y="class", cmap="viridis")

# %%
df=sns.load_dataset("titanic")
sns.displot(df, x="alive", y="sex", cmap="viridis")

# %%
df=sns.load_dataset("titanic")
sns.displot(df, x="sex", y="embark_town", cmap="viridis")

# %%
sns.displot(df, x="sex", hue="survived")

# %%
sns.displot(df, x="class", hue="alive")

# %%
sns.displot(df, x="alive", shrink=.8)

# %%
sns.displot(df, x="fare", hue="pclass", bins=50)

# %%
df=sns.load_dataset("penguins")
sns.get_dataset_names()
sns.displot(df, x="flipper_length_mm")

# %%
df=sns.load_dataset("penguins")
sns.displot(df, x="flipper_length_mm", discrete=True)

# %%
sns.displot(df, x="flipper_length_mm", hue="species")

# %%
sns.displot(df, x="flipper_length_mm", col="sex")

# %%
sns.displot(df, x="flipper_length_mm", kind="kde")

# %%
sns.displot(df, x="flipper_length_mm", hue="species", kind="kde")

# %%
sns.displot(df, x="flipper_length_mm", y="bill_depth_mm")

# %%
sns.displot(df, x="flipper_length_mm", y="bill_depth_mm", hue="species")

# %% [markdown]
# ##Histplot

# %%
df= sns.load_dataset("penguins")
sns.histplot(df["flipper_length_mm"])
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(df["bill_depth_mm"])
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
sns.histplot(df["bill_depth_mm"], kde=True)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
sns.histplot(df["bill_depth_mm"], bins=50)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %% [markdown]
# ##Jointplot

# %%
df= sns.load_dataset("penguins")
sns.jointplot(df, x='bill_length_mm', y="bill_depth_mm")

# %%
df.sort_values("bill_length_mm", ascending=False)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 253     Gentoo     Biscoe            59.6           17.0              230.0
# 169  Chinstrap      Dream            58.0           17.8              181.0
# 321     Gentoo     Biscoe            55.9           17.0              228.0
# 215  Chinstrap      Dream            55.8           19.8              207.0
# 335     Gentoo     Biscoe            55.1           16.0              230.0
# ..         ...        ...             ...            ...                ...
# 70      Adelie  Torgersen            33.5           19.0              190.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 142     Adelie      Dream            32.1           15.5              188.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 339     Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g     sex
# 253       6050.0    Male
# ...

# %%
sns.jointplot (
    data=df,
    x="bill_depth_mm", y="bill_length_mm", hue="species",
)

# %% [markdown]
# ##KdePlot

# %%
df= sns.load_dataset("penguins")
sns.kdeplot(df["bill_length_mm"])
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %% [markdown]
# ##Pairplot

# %%
df= sns.load_dataset("penguins")
sns.pairplot(df)

# %%
df= sns.load_dataset("tips")
sns.pairplot(df)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(df, hue="sex", palette="Reds")

# %%
sns.pairplot(df, hue="smoker", palette="viridis")

# %% [markdown]
# ##Relplot

# %%
df= sns.load_dataset("tips")
sns.relplot(data=df, x="total_bill", y="tip")

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="time")

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="time", col="sex")

# %% [markdown]
# ##Scatterplot

# %%
df= sns.load_dataset("tips")
sns.scatterplot(df, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(df, x="total_bill", y="tip", hue="size", palette="viridis")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ##Ecdfplot

# %%
df= sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.ecdfplot(df, x="bill_depth_mm")
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Proportion'>

# %%
df= sns.load_dataset("tips")
sns.ecdfplot(df, x="tip")
# Out:
# <Axes: xlabel='tip', ylabel='Proportion'>

# %% [markdown]
# ##Lineplot

# %%
df=sns.load_dataset("flights")
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.lineplot(data=df, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=df, x="year", y="passengers", hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ##Rugplot

# %%
df= sns.load_dataset("tips")
sns.rugplot(df, x="total_bill")
# Out:
# <Axes: xlabel='total_bill'>

# %%
df = sns.load_dataset("tips")
sns.rugplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.kdeplot(df["total_bill"])
sns.rugplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.scatterplot(data=df, x="total_bill", y="tip")
sns.rugplot(data=df, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df, x="total_bill", y="tip")
sns.rugplot(data=df, x="total_bill", y="tip", height=.15)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ##Barplot

# %%
df= sns.load_dataset("tips")
sns.barplot(data=df, x="sex", y="total_bill", color="crimson")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="sex", y="total_bill", data=df, color="silver", estimator=np.cov) # mean() by default
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ##Countplot

# %%
sns.countplot(df, x="sex", color="gold")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
ax = sns.countplot(x='sex', data=df, color="gold")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '157'), Text(0, 0, '87')]

# %% [markdown]
# ##Boxplot

# %%
df= sns.load_dataset("tips")
sns.boxplot(data=df, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=df, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=df, hue="sex")
plt.legend(loc=2)

# %% [markdown]
# ##Violinplot

# %%
df= sns.load_dataset("tips")
sns.violinplot(data=df, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=df, hue="sex", split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ##Stripplot

# %%
df= sns.load_dataset("tips")
sns.stripplot(data=df, x="day", y="total_bill", color="red")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=df, jitter=True, hue="sex", dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ##Swarmplot

# %%
sns.swarmplot(x="day", y="total_bill", data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=df, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=df, hue='sex', palette='viridis')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=df)
sns.swarmplot(x="day", y="total_bill", data=df, color="white")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ##Heatmap

# %%
df = sns.load_dataset("tips")
df_corr= df.corr(numeric_only=True)
sns.heatmap(df_corr, annot=True, cmap="viridis")
# Out:
# <Axes: >

# %%
df = sns.load_dataset("penguins")
df_corr= df.corr(numeric_only=True)
sns.heatmap(df_corr, annot=True, cmap="viridis")
# Out:
# <Axes: >

# %%
sns.heatmap(df_corr, annot=True, linewidth=.5, cmap='viridis')
# Out:
# <Axes: >

# %%
df= sns.load_dataset("flights")
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df_pivot= df.pivot_table(index="month", columns="year", values="passengers")
df_pivot.head()
# Out:
# /tmp/ipython-input-3388455620.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df_pivot= df.pivot_table(index="month", columns="year", values="passengers")
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0

# %%
df_pivot= df.pivot_table(index="month", columns="year", values="passengers")
df_pivot.tail()
# Out:
# /tmp/ipython-input-500936687.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df_pivot= df.pivot_table(index="month", columns="year", values="passengers")
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# Dec    118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0  337.0
#
# year    1959   1960
# month
# Aug    559.0  606.0
# Sep    463.0  508.0
# Oct    407.0  461.0
# Nov    362.0  390.0
# Dec    405.0  432.0

# %%
sns.heatmap(df_pivot, cmap="viridis", linecolor="white", linewidth=.5)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ##Clustermap

# %%
sns.clustermap(df_pivot, cmap="viridis", standard_scale=1)

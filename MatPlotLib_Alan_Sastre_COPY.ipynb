# %% [markdown]
# <a href="https://colab.research.google.com/github/rmonterof/Python/blob/main/MatPlotLib_Alan_Sastre_COPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %% [markdown]
# www.matplotlib.org
# www.python-graph-gallery.com

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ##Líneas

# %%
plt.plot([1.5, 3.0, 4.0])

# %%
plt.plot([1.5, 3.0, 4.0])
plt.title("Título del gráfico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
# Out:
# Text(0, 0.5, 'Eje Y')

# %%
plt.plot([1.5, 3.0, 4.0])
plt.plot([3.5, 3.0, 1.0])
plt.title("Título del gráfico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
# Out:
# Text(0, 0.5, 'Eje Y')

# %%
plt.plot(np.array([1.5, 3.0, 4.0]))  #numpy & matplotlib son librerías compatibles y por eso es fácil integrarlas, el resultado es el mismo
plt.plot(np.array([3.5, 3.0, 1.0]))
plt.title("Título del gráfico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
# Out:
# Text(0, 0.5, 'Eje Y')

# %%
arr_2d = np.array([1.5, 3.0, 4.0, 5.0, 7.0, 2.0, 4.3, 5.1, 9.9, 1.0]).reshape(5,2)
print(arr_2d)
# Out:
# [[1.5 3. ]
#  [4.  5. ]
#  [7.  2. ]
#  [4.3 5.1]
#  [9.9 1. ]]

# %%
plt.plot(arr_2d)
# Out:
# [<matplotlib.lines.Line2D at 0x7bc1501b3680>,
#  <matplotlib.lines.Line2D at 0x7bc1501b36b0>]

# %%
x = np.array([1.1, 2.0, 4.0, 5.0])
y = np.array([1.0, 1.5, 1.9, 2.5])
plt.plot(x,y)

# %%
x = np.array([1.1, 2.0, 4.0, 5.0])
y = np.array([1.0, 1.5, 1.9, 2.5])
plt.plot(x,y, 'r--')

# %%
x = np.array([1.1, 2.0, 4.0, 5.0])
y = np.array([1.0, 1.5, 1.9, 2.5])
plt.plot(x,y, 'g*-')

# %% [markdown]
# ##Barras

# %%
x = np.array(["Producto1", "Producto2", "Producto3", "Producto4"])
y = np.array([5.0, 9.99, 7.99, 3.21])
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["Producto1", "Producto2", "Producto3", "Producto4"])
y = np.array([5.0, 9.99, 7.99, 3.21])
plt.barh(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["Producto1", "Producto2", "Producto3", "Producto4"])
y = np.array([5.0, 9.99, 7.99, 3.21])
plt.barh(x,y, color = "purple")
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["Producto1", "Producto2", "Producto3", "Producto4"])
y = np.array([5.0, 9.99, 7.99, 3.21])

index = np.arange(len(x))
index
# Out:
# array([0, 1, 2, 3])

# %%
x = np.array(["Producto1", "Producto2", "Producto3", "Producto4"])
y = np.array([5.0, 9.99, 7.99, 3.21])

index = np.arange(len(x))
plt.bar(index, y)
plt.xticks(index, x)
plt.title("Precios")
# Out:
# Text(0.5, 1.0, 'Precios')

# %%
df = pd.Series({
    "Producto" :["Producto1", "Producto2", "Producto3", "Producto4"],
    "Precios" : [5.0, 9.99, 7.99, 3.21]
})

plt.bar(df["Producto"], df["Precios"])
# Out:
# <BarContainer object of 4 artists>

# %%
etiquetas = ['Enero', 'Febrero', 'Marzo']
ingresos = [1500.0, 2000.0, 1700.0]
gastos= [1200.0, 1000.0, 800.0]

index = np.arange(len(etiquetas))
plt.bar(index, ingresos, color= "green")
plt.bar(index, gastos, color= "red")
plt.xticks(index, etiquetas)
# Out:
# ([<matplotlib.axis.XTick at 0x7bc1502da870>,
#   <matplotlib.axis.XTick at 0x7bc149bcb440>,
#   <matplotlib.axis.XTick at 0x7bc14891fda0>],
#  [Text(0, 0, 'Enero'), Text(1, 0, 'Febrero'), Text(2, 0, 'Marzo')])

# %% [markdown]
# ## Histogramas

# %%
x = np.random.normal (170, 10, 250)
x
# Out:
# array([166.26981063, 167.99713977, 164.90474438, 176.15086491,
#        183.75416898, 168.7316651 , 181.62986524, 166.7259716 ,
#        180.66940608, 162.76132305, 179.42385258, 180.70427912,
#        162.43661382, 167.0575524 , 182.28407512, 180.49939883,
#        159.34899398, 179.16114301, 182.51694734, 181.81211216,
#        174.43443983, 173.36384109, 175.64585041, 159.91625864,
#        159.75110369, 167.9900715 , 169.38922001, 167.34254107,
#        173.40349456, 183.64511812, 161.70424698, 167.05416584,
#        168.89055659, 178.20830111, 189.47636748, 167.38160413,
#        179.92415703, 172.61416213, 180.94866774, 179.75883146,
#        176.94511763, 182.53318485, 174.88691677, 168.90698649,
#        167.91380209, 166.60098909, 157.47388792, 193.52813809,
#        176.81927072, 162.48327631, 174.04161812, 170.51915575,
#        176.93340013, 188.1934387 , 159.75705368, 175.24075358,
#        181.1012574 , 174.26217235, 171.32638677, 169.49564898,
#        162.68251747, 155.29964669, 175.31357448, 183.98033452,
#        171.78145388, 154.6671079 , 180.76265569, 151.16636382,
#        166.3368511 , 161.21862414, 170.78854769, 166.24852673,
#        153.93124074, 173.63221418, 166.87568984, 173.23756283,
#        179.84063109, 176.46137024, 162.66781433, 173.74909186,
#        161.84885507, 176.91021879, 162.49437094, 178.52037207,
#        152.00544029, 184.0074164 , 181.17137139, 170.68075784,
#        162.32908078, 156.85716669, 153.18407094, 166.49936928,
#        171.89618335, 157.3767654 , 163.85515321, 171.85629587,
#        180.75229437, 183.91138211, 168.95546868, 172.38741703,
#        167.47752323, 171.58398066, 157.54065541, 154.53162765,
#        173.8283962 , 201.10810135, 172.12795447, 157.29213843,
#        162.98375008, 174.07764998, 176.30065795, 143.02438077,
#        181.9971861 , 157.6771656 , 180.03832008, 162.13565998,
#        161.8586903 , 168.0630381 , 159.6248682 , 153.29580186,
#        185.75564897, 167.55358925, 187.57348233, 154.11712633,
#        156.52021695, 161.981276  , 170.71068535, 177.86006472,
#        163.88704495, 170.10682711, 167.18168661, 169.88048382,
#        176.84540998, 156.33535508, 175.3431974 , 159.37240018,
#        162.20891754, 178.89002956, 167.92444   , 192.38549808,
#        170.09039743, 168.17647029, 182.36899138, 164.58012482,
#        160.58256292, 175.77377685, 168.55590162, 172.60215599,
#        186.40131429, 163.92558872, 141.15706369, 183.61848517,
#        180.04314326, 155.18281477, 184.42972932, 174.30059373,
#        168.04476746, 177.56696429, 160.55445892, 168.75257672,
#        169.88966572, 162.63104608, 162.62835854, 171.63245596,
#        174.77549847, 173.09775334, 154.46317391, 172.26628804,
#        177.50841129, 171.31288863, 158.01405776, 179.51170814,
#        187.97250245, 155.89607766, 193.59841407, 179.01747125,
#        163.05421628, 163.72969839, 172.53116447, 191.39189496,
#        164.56818353, 169.21655262, 156.71735214, 168.93708575,
#        168.44293918, 167.71726032, 170.75113054, 173.42843023,
#        176.66259098, 163.92397401, 164.5656121 , 168.62226219,
#        163.30163121, 170.90749906, 163.04803431, 160.62994363,
#        165.50384361, 175.56823946, 172.34632667, 185.00771655,
#        167.19630165, 171.56448907, 173.30272804, 183.35512293,
#        157.13183928, 171.3793517 , 162.23560694, 165.75965795,
#        175.88739036, 165.5571664 , 176.55478193, 167.29826406,
#        177.7446324 , 176.33027041, 164.39564798, 184.5488895 ,
#        164.00010928, 177.45423957, 166.91876359, 164.98984151,
#        174.20357202, 175.44458451, 179.07199482, 172.02397037,
#        186.77595272, 172.6889452 , 168.30438239, 175.59802044,
#        180.051833  , 170.78314366, 178.69047147, 180.36946673,
#        175.81148947, 164.83404389, 181.92721996, 174.39074405,
#        167.59571952, 186.18694996, 159.06217419, 168.42579914,
#        179.51972683, 177.66026141, 157.35241157, 164.89436825,
#        165.85235515, 168.72454366, 173.37855755, 169.8366495 ,
#        182.8116922 , 167.37279187])

# %%
plt.hist(x)
# Out:
# (array([ 2.,  2., 23., 44., 58., 58., 40., 17.,  5.,  1.]),
#  array([141.15706369, 147.15216745, 153.14727122, 159.14237499,
#         165.13747875, 171.13258252, 177.12768628, 183.12279005,
#         189.11789382, 195.11299758, 201.10810135]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.normal (170, 10, 250)

plt.hist(x, bins=20, alpha=0.75, color='green', linewidth= 1.0, edgecolor="k")
plt.xlabel("valores")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

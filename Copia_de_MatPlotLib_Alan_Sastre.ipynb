# %% [markdown]
# <a href="https://colab.research.google.com/github/rmonterof/Python/blob/main/Copia_de_MatPlotLib_Alan_Sastre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %% [markdown]
# www.matplotlib.org
# www.python-graph-gallery.com

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ##Líneas

# %%
plt.plot([1.5, 3.0, 4.0])

# %%
plt.plot([1.5, 3.0, 4.0])
plt.title("Título del gráfico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
# Out:
# Text(0, 0.5, 'Eje Y')

# %%
plt.plot([1.5, 3.0, 4.0])
plt.plot([3.5, 3.0, 1.0])
plt.title("Título del gráfico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
# Out:
# Text(0, 0.5, 'Eje Y')

# %%
plt.plot(np.array([1.5, 3.0, 4.0]))  #numpy & matplotlib son librerías compatibles y por eso es fácil integrarlas, el resultado es el mismo
plt.plot(np.array([3.5, 3.0, 1.0]))
plt.title("Título del gráfico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
# Out:
# Text(0, 0.5, 'Eje Y')

# %%
arr_2d = np.array([1.5, 3.0, 4.0, 5.0, 7.0, 2.0, 4.3, 5.1, 9.9, 1.0]).reshape(5,2)
print(arr_2d)
# Out:
# [[1.5 3. ]
#  [4.  5. ]
#  [7.  2. ]
#  [4.3 5.1]
#  [9.9 1. ]]

# %%
plt.plot(arr_2d)

# %%
x = np.array([1.1, 2.0, 4.0, 5.0])
y = np.array([1.0, 1.5, 1.9, 2.5])
plt.plot(x,y)

# %%
x = np.array([1.1, 2.0, 4.0, 5.0])
y = np.array([1.0, 1.5, 1.9, 2.5])
plt.plot(x,y, 'r--')

# %%
x = np.array([1.1, 2.0, 4.0, 5.0])
y = np.array([1.0, 1.5, 1.9, 2.5])
plt.plot(x,y, 'g*-')

# %% [markdown]
# ##Barras

# %%
x = np.array(["Producto1", "Producto2", "Producto3", "Producto4"])
y = np.array([5.0, 9.99, 7.99, 3.21])
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["Producto1", "Producto2", "Producto3", "Producto4"])
y = np.array([5.0, 9.99, 7.99, 3.21])
plt.barh(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["Producto1", "Producto2", "Producto3", "Producto4"])
y = np.array([5.0, 9.99, 7.99, 3.21])
plt.barh(x,y, color = "purple")
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["Producto1", "Producto2", "Producto3", "Producto4"])
y = np.array([5.0, 9.99, 7.99, 3.21])

index = np.arange(len(x))
index
# Out:
# array([0, 1, 2, 3])

# %%
x = np.array(["Producto1", "Producto2", "Producto3", "Producto4"])
y = np.array([5.0, 9.99, 7.99, 3.21])

index = np.arange(len(x))
plt.bar(index, y)
plt.xticks(index, x)
plt.title("Precios")
# Out:
# Text(0.5, 1.0, 'Precios')

# %%
df = pd.Series({
    "Producto" :["Producto1", "Producto2", "Producto3", "Producto4"],
    "Precios" : [5.0, 9.99, 7.99, 3.21]
})

plt.bar(df["Producto"], df["Precios"])
# Out:
# <BarContainer object of 4 artists>

# %%
etiquetas = ['Enero', 'Febrero', 'Marzo']
ingresos = [1500.0, 2000.0, 1700.0]
gastos= [1200.0, 1000.0, 1800.0]

index = np.arange(len(etiquetas))
plt.bar(index, ingresos, color= "green")
plt.bar(index, gastos, color= "red")
plt.xticks(index, etiquetas)
# Out:
# ([<matplotlib.axis.XTick at 0x7b435de6ff80>,
# ...
#  [Text(0, 0, 'Enero'), Text(1, 0, 'Febrero'), Text(2, 0, 'Marzo')])

# %% [markdown]
# ## Histogramas

# %%
x = np.random.normal (170, 10, 250)
x
# Out:
# array([174.80224681, 160.48272564, 170.78238549, 185.79414884,
#        171.09631479, 176.17885513, 179.82393946, 176.9978667 ,
#        169.07542784, 147.37436591, 163.38879508, 177.63643705,
#        160.57076702, 164.43305019, 163.89295493, 183.03473497,
#        164.12140462, 176.12461038, 163.12033127, 163.02597006,
#        175.70371881, 174.00229701, 165.39023639, 175.75659153,
#        143.29358604, 177.66318622, 162.34755274, 169.19043824,
#        175.67087183, 173.94482446, 176.32657481, 180.97392344,
#        154.01537375, 188.98058627, 164.80699535, 175.03481926,
#        150.59118764, 173.97252311, 164.4243591 , 186.93445163,
#        171.85256129, 179.42176827, 158.66593452, 177.06341758,
#        175.83948199, 156.61351368, 165.13819067, 154.94359291,
#        165.21530409, 149.26883931, 181.45304562, 183.89955443,
#        160.88446879, 168.34875857, 163.02891878, 165.80929467,
#        176.47222857, 173.90246239, 171.91115767, 179.48486605,
# ...

# %%
plt.hist(x)
# Out:
# (array([ 3., 10., 10., 34., 40., 60., 41., 34., 12.,  6.]),
#  array([140.60285942, 145.9272465 , 151.25163358, 156.57602066,
#         161.90040774, 167.22479481, 172.54918189, 177.87356897,
#         183.19795605, 188.52234313, 193.84673021]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.normal (170, 10, 250)

plt.hist(x, bins=20, alpha=0.75, color='green', linewidth= 1.0, edgecolor="k")
plt.xlabel("valores")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')
